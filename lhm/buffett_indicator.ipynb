# %% [markdown]
# # buffett_indicator

# %%
# file path
# ./EDA_file/buffett_indicator/xxxx.csv
# GDP.csv
# NCBEILQ027S.csv > MV.csv (Market Value)

# %%
# import module
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import plotly
import plotly.express as px

# %%
# data check - 1 - GDP
gdp = pd.read_csv("./EDA_file/buffett_indicator/GDP.csv")

# %%
# data check - 1 - GDP
gdp.head(15)
# Out:
#           DATE      GDP
# 0   1947-01-01  243.164
# 1   1947-04-01  245.968
# 2   1947-07-01  249.585
# 3   1947-10-01  259.745
# 4   1948-01-01  265.742
# 5   1948-04-01  272.567
# 6   1948-07-01  279.196
# 7   1948-10-01  280.366
# 8   1949-01-01  275.034
# 9   1949-04-01  271.351
# 10  1949-07-01  272.889
# 11  1949-10-01  270.627
# 12  1950-01-01  280.828
# 13  1950-04-01  290.383
# 14  1950-07-01  308.153

# %%
# data visualization - 1 - GDP
plt.figure(figsize=(60, 30))
fig = px.line(gdp, x="DATE", y="GDP")
fig.show()
# Out:
# <div>                            <div id="a29b21ec-c665-474b-bb00-caf4df2cd81b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a29b21ec-c665-474b-bb00-caf4df2cd81b")) {                    Plotly.newPlot(                        "a29b21ec-c665-474b-bb00-caf4df2cd81b",                        [{"hovertemplate":"DATE=%{x}<br>GDP=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1947-01-01","1947-04-01","1947-07-01","1947-10-01","1948-01-01","1948-04-01","1948-07-01","1948-10-01","1949-01-01","1949-04-01","1949-07-01","1949-10-01","1950-01-01","1950-04-01","1950-07-01","1950-10-01","1951-01-01","1951-04-01","1951-07-01","1951-10-
# ...

# %%
# data check - 2 - MV
mv = pd.read_csv("./EDA_file/buffett_indicator/MV.csv")

# %%
# data check - 2 - MV
mv.head(15)

# NaN 값 존재로 전처리 필요할듯
# Out:
#           DATE      MV
# 0   1945-10-01  103694
# 1   1946-01-01       .
# 2   1946-04-01       .
# 3   1946-07-01       .
# 4   1946-10-01   97302
# 5   1947-01-01       .
# 6   1947-04-01       .
# 7   1947-07-01       .
# 8   1947-10-01   95116
# 9   1948-01-01       .
# 10  1948-04-01       .
# 11  1948-07-01       .
# 12  1948-10-01   94141
# 13  1949-01-01       .
# 14  1949-04-01       .

# %%
# data visualization - 2 - MV
plt.figure(figsize=(40, 30))
fig = px.line(mv, x="DATE", y="MV")
fig.show()
# Out:
# <div>                            <div id="eb54589b-8fc6-4022-9803-c17568720860" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb54589b-8fc6-4022-9803-c17568720860")) {                    Plotly.newPlot(                        "eb54589b-8fc6-4022-9803-c17568720860",                        [{"hovertemplate":"DATE=%{x}<br>MV=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1945-10-01","1946-01-01","1946-04-01","1946-07-01","1946-10-01","1947-01-01","1947-04-01","1947-07-01","1947-10-01","1948-01-01","1948-04-01","1948-07-01","1948-10-01","1949-01-01","1949-04-01","1949-07-01","1949-10-01","1950-01-01","1950-04-01","1950-07-0
# ...

# %% [markdown]
# # xls to csv

# %%
# House Sale Price_Monthly_Trend
# file name = house_sale_price_monthly_trend

# %%
# # pip 설치 내용
# pip install xlrd
# pip install openpyxl
# pip install pandas

# %%
# import
import pandas as pd

# %%
# test 1
xls = pd.read_excel("./EDA_file/house_sale_price_monthly_trend.xls")
xls.to_csv("./EDA_file/house_sale_price_monthly_trend.csv")

# %%
# verify
data = pd.read_csv("./EDA_file/house_sale_price_monthly_trend.csv")
data.head(10)
# Out:
#    Unnamed: 0 통계표명:           주택매매가격 동향 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           0   단위:                   %        NaN        NaN        NaN
# 1           1   NaN             200601월    200602월    200603월    200604월
# 2           2    전국                 0.3        0.5        0.6        0.9
# 3           3   수도권                 0.5        0.7        1.0        1.4
# 4           4    서울                 0.6        0.8        1.2        1.5
# 5           5    강남                 1.0        1.2        1.8        2.3
# 6           6    강북                 0.2        0.3        0.5        0.7
# 7           7   출처:  한국부동산원「전국주택가격동향조사」        NaN        NaN        NaN
# 8           8   주석:      월별 주택 매매가격 증감률        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  ... Unnamed: 191 Unnamed: 192  \
# 0        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1    200605월    200606월    200607월    200608월  ...      202111월      202112월
# ...

# %%
data
# Out:
#    Unnamed: 0 통계표명:           주택매매가격 동향 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0           0   단위:                   %        NaN        NaN        NaN
# 1           1   NaN             200601월    200602월    200603월    200604월
# 2           2    전국                 0.3        0.5        0.6        0.9
# 3           3   수도권                 0.5        0.7        1.0        1.4
# 4           4    서울                 0.6        0.8        1.2        1.5
# 5           5    강남                 1.0        1.2        1.8        2.3
# 6           6    강북                 0.2        0.3        0.5        0.7
# 7           7   출처:  한국부동산원「전국주택가격동향조사」        NaN        NaN        NaN
# 8           8   주석:      월별 주택 매매가격 증감률        NaN        NaN        NaN
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  ... Unnamed: 191 Unnamed: 192  \
# 0        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1    200605월    200606월    200607월    200608월  ...      202111월      202112월
# ...

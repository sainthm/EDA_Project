# %% [markdown]
# # 한국 부동산원 지표
#
# ### 월간 매매가격지수
#  - 전국(종합주택)
#
#  - 전국(아파트)
#
#  - 서울(아파트)
#
#  - 강남3구(아파트)
#
#
# ### 아파트 주간 매매가격지수
#  - 문제인 정권
#
#  - 2019년 문제인정권
#
#  - 박근혜 정권

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
apt = pd.read_excel('./data/월간_매매가격지수_아파트.xlsx')
gangnam = pd.read_excel('./data/월간_매매가격지수_아파트_강남3구.xlsx')
country = pd.read_excel('./data/월간_매매가격지수_종합.xlsx')
seoul =  pd.read_excel('./data/월간_매매가격지수_아파트_서울.xlsx')

# %% [markdown]
# ## 월간 종합 주택 매매지수
# ------------

# %%
country
# Out:
#    2004년 01월  Unnamed: 1  2004년 02월  Unnamed: 3  2004년 03월  Unnamed: 5  \
# 0     60.652       -0.51     60.744        0.15     60.842        0.16
#
#    2004년 04월  Unnamed: 7  2004년 05월  Unnamed: 9  ...  2022년 04월  Unnamed: 439  \
# 0     60.936        0.15     60.917       -0.03  ...     104.83          0.06
#
#    2022년 05월  Unnamed: 441  2022년 06월  Unnamed: 443  2022년 07월  Unnamed: 445  \
# 0    104.844          0.01    104.837         -0.01    104.758         -0.08
#
#    2022년 08월  Unnamed: 447
# 0    104.459         -0.29
#
# [1 rows x 448 columns]

# %%
country = country[country.columns.drop(list(country.filter(regex='Unnamed')))]
country
# Out:
#    2004년 01월  2004년 02월  2004년 03월  2004년 04월  2004년 05월  2004년 06월  \
# 0     60.652     60.744     60.842     60.936     60.917     60.752
#
#    2004년 07월  2004년 08월  2004년 09월  2004년 10월  ...  2021년 11월  2021년 12월  \
# 0     60.584      60.34     60.189     60.036  ...    104.317    104.617
#
#    2022년 01월  2022년 02월  2022년 03월  2022년 04월  2022년 05월  2022년 06월  \
# 0    104.719     104.75    104.768     104.83    104.844    104.837
#
#    2022년 07월  2022년 08월
# 0    104.758    104.459
#
# [1 rows x 224 columns]

# %%
country_col = country.columns
country_col
# Out:
# Index(['2004년 01월', '2004년 02월', '2004년 03월', '2004년 04월', '2004년 05월',
#        '2004년 06월', '2004년 07월', '2004년 08월', '2004년 09월', '2004년 10월',
#        ...
#        '2021년 11월', '2021년 12월', '2022년 01월', '2022년 02월', '2022년 03월',
#        '2022년 04월', '2022년 05월', '2022년 06월', '2022년 07월', '2022년 08월'],
#       dtype='object', length=224)

# %%
country_val = country.values
country_val
# Out:
# array([[ 60.652,  60.744,  60.842,  60.936,  60.917,  60.752,  60.584,
#          60.34 ,  60.189,  60.036,  59.731,  59.454,  59.286,  59.457,
#          59.679,  60.006,  60.306,  60.769,  61.236,  61.461,  61.617,
#          61.609,  61.599,  61.7  ,  61.894,  62.147,  62.546,  63.06 ,
#          63.644,  63.966,  64.123,  64.277,  64.685,  65.567,  67.542,
#          68.843,  69.731,  70.138,  70.403,  70.625,  70.768,  70.958,
#          71.233,  71.457,  71.815,  72.205,  72.603,  72.846,  73.196,
#          73.527,  74.305,  75.196,  75.91 ,  76.783,  77.351,  77.706,
#          78.093,  78.093,  77.724,  77.117,  76.694,  76.519,  76.396,
#          76.44 ,  76.528,  76.677,  76.889,  77.135,  77.675,  77.964,
#          78.155,  78.27 ,  78.369,  78.573,  78.747,  78.884,  78.904,
#          78.902,  78.778,  78.699,  78.75 ,  78.884,  79.141,  79.411,
#          79.737,  80.294,  80.993,  81.916,  82.039,  82.422,  82.749,
#          83.15 ,  83.566,  83.871,  84.169,  84.284,  84.49 ,  84.496,
#          84.514,  84.464,  84.388,  84.204,  83.981,  83.744,  83.547,
#          83.389,  83.253,  83.077,  82.863,  82.721,  82.656,  82.754,
#          82.896,  82.925,  82.867,  82.758,  82.797,  83.034,  83.196,
#          83.33 ,  83.528,  83.697,  83.891,  83.945,  83.963,  83.978,
#          84.008,  84.085,  84.287,  84.489,  84.635,  84.754,  84.876,
#          85.047,  85.306,  85.672,  85.959,  86.284,  86.527,  86.758,
#          87.041,  87.327,  87.597,  87.729,  87.768,  87.768,  87.764,
#          87.78 ,  87.81 ,  87.845,  87.884,  87.946,  88.015,  88.161,
#          88.295,  88.353,  88.368,  88.381,  88.431,  88.517,  88.644,
#          88.832,  88.992,  89.212,  89.323,  89.44 ,  89.557,  89.658,
#          89.787,  89.964,  90.075,  90.126,  90.103,  90.083,  90.065,
#          90.086,  90.365,  90.536,  90.651,  90.646,  90.513,  90.407,
#          90.262,  90.076,  89.932,  89.816,  89.735,  89.691,  89.704,
#          89.809,  89.98 ,  90.323,  90.571,  90.877,  91.369,  91.618,
#          91.742,  92.118,  92.683,  93.121,  93.515,  93.812,  94.317,
#          95.164,  95.917,  96.775,  97.487,  98.175,  98.862, 100.   ,
#         100.853, 101.823, 102.756, 103.664, 104.317, 104.617, 104.719,
#         104.75 , 104.768, 104.83 , 104.844, 104.837, 104.758, 104.459]])

# %%
# country=country.transpose()
# country
country = pd.DataFrame(index=country_col, data=country_val.T)
country
# Out:
#                  0
# 2004년 01월   60.652
# 2004년 02월   60.744
# 2004년 03월   60.842
# 2004년 04월   60.936
# 2004년 05월   60.917
# ...            ...
# 2022년 04월  104.830
# 2022년 05월  104.844
# 2022년 06월  104.837
# 2022년 07월  104.758
# 2022년 08월  104.459
#
# [224 rows x 1 columns]

# %%
def change_date_to_time(x):
    x = x.replace("년 ", "-")
    x = x.replace("월", " ")
#     x = x.replace("일", " ")
    return x

# %%
country.reset_index()["index"].apply(change_date_to_time)
# Out:
# 0      2004-01
# 1      2004-02
# 2      2004-03
# 3      2004-04
# 4      2004-05
#          ...
# 219    2022-04
# 220    2022-05
# 221    2022-06
# 222    2022-07
# 223    2022-08
# Name: index, Length: 224, dtype: object

# %%
country = country.reset_index()
country["index"] = country["index"].apply(change_date_to_time)
country
# Out:
#         index        0
# 0    2004-01    60.652
# 1    2004-02    60.744
# 2    2004-03    60.842
# 3    2004-04    60.936
# 4    2004-05    60.917
# ..        ...      ...
# 219  2022-04   104.830
# 220  2022-05   104.844
# 221  2022-06   104.837
# 222  2022-07   104.758
# 223  2022-08   104.459
#
# [224 rows x 2 columns]

# %%
country.columns = ['Date', 'Price_index']
country
# Out:
#          Date  Price_index
# 0    2004-01        60.652
# 1    2004-02        60.744
# 2    2004-03        60.842
# 3    2004-04        60.936
# 4    2004-05        60.917
# ..        ...          ...
# 219  2022-04       104.830
# 220  2022-05       104.844
# 221  2022-06       104.837
# 222  2022-07       104.758
# 223  2022-08       104.459
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=country, x='Date', y='Price_index')
plt.show()

# %% [markdown]
# ## 월간 전국 아파트 매매 지수
#
# ------

# %%
apt
# Out:
#    2004년 01월  Unnamed: 1  2004년 02월  Unnamed: 3  2004년 03월  Unnamed: 5  \
# 0      54.96       -0.24     55.144        0.34     55.364         0.4
#
#    2004년 04월  Unnamed: 7  2004년 05월  Unnamed: 9  ...  2022년 04월  Unnamed: 439  \
# 0     55.599        0.42     55.665        0.12  ...    106.198             0
#
#    2022년 05월  Unnamed: 441  2022년 06월  Unnamed: 443  2022년 07월  Unnamed: 445  \
# 0    106.145         -0.05    106.034          -0.1    105.825          -0.2
#
#    2022년 08월  Unnamed: 447
# 0    105.286         -0.51
#
# [1 rows x 448 columns]

# %%
apt = apt[apt.columns.drop(list(apt.filter(regex='Unnamed')))]
apt
# Out:
#    2004년 01월  2004년 02월  2004년 03월  2004년 04월  2004년 05월  2004년 06월  \
# 0      54.96     55.144     55.364     55.599     55.665     55.609
#
#    2004년 07월  2004년 08월  2004년 09월  2004년 10월  ...  2021년 11월  2021년 12월  \
# 0     55.527     55.353     55.259     55.196  ...    105.857    106.204
#
#    2022년 01월  2022년 02월  2022년 03월  2022년 04월  2022년 05월  2022년 06월  \
# 0    106.284    106.262    106.203    106.198    106.145    106.034
#
#    2022년 07월  2022년 08월
# 0    105.825    105.286
#
# [1 rows x 224 columns]

# %%
apt_col =apt.columns
apt_col
# Out:
# Index(['2004년 01월', '2004년 02월', '2004년 03월', '2004년 04월', '2004년 05월',
#        '2004년 06월', '2004년 07월', '2004년 08월', '2004년 09월', '2004년 10월',
#        ...
#        '2021년 11월', '2021년 12월', '2022년 01월', '2022년 02월', '2022년 03월',
#        '2022년 04월', '2022년 05월', '2022년 06월', '2022년 07월', '2022년 08월'],
#       dtype='object', length=224)

# %%
apt_val = apt.values

# %%
apt = pd.DataFrame(index=apt_col, data=apt_val.T)
apt
# Out:
#                  0
# 2004년 01월   54.960
# 2004년 02월   55.144
# 2004년 03월   55.364
# 2004년 04월   55.599
# 2004년 05월   55.665
# ...            ...
# 2022년 04월  106.198
# 2022년 05월  106.145
# 2022년 06월  106.034
# 2022년 07월  105.825
# 2022년 08월  105.286
#
# [224 rows x 1 columns]

# %%
apt.reset_index()["index"].apply(change_date_to_time)
# Out:
# 0      2004-01
# 1      2004-02
# 2      2004-03
# 3      2004-04
# 4      2004-05
#          ...
# 219    2022-04
# 220    2022-05
# 221    2022-06
# 222    2022-07
# 223    2022-08
# Name: index, Length: 224, dtype: object

# %%
apt = apt.reset_index()
apt["index"] = apt["index"].apply(change_date_to_time)
apt
# Out:
#         index        0
# 0    2004-01    54.960
# 1    2004-02    55.144
# 2    2004-03    55.364
# 3    2004-04    55.599
# 4    2004-05    55.665
# ..        ...      ...
# 219  2022-04   106.198
# 220  2022-05   106.145
# 221  2022-06   106.034
# 222  2022-07   105.825
# 223  2022-08   105.286
#
# [224 rows x 2 columns]

# %%
apt.columns = ['Date', 'Price_index']
apt
# Out:
#          Date  Price_index
# 0    2004-01        54.960
# 1    2004-02        55.144
# 2    2004-03        55.364
# 3    2004-04        55.599
# 4    2004-05        55.665
# ..        ...          ...
# 219  2022-04       106.198
# 220  2022-05       106.145
# 221  2022-06       106.034
# 222  2022-07       105.825
# 223  2022-08       105.286
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=apt, x='Date', y='Price_index')
plt.show()

# %% [markdown]
# ## 월간 서울 아파트 매매 지수
#
# -----

# %%
seoul
# Out:
#    2004년 01월  Unnamed: 1  2004년 02월  Unnamed: 3  2004년 03월  Unnamed: 5  \
# 0     51.936        -0.3     52.246         0.6     52.519        0.52
#
#    2004년 04월  Unnamed: 7  2004년 05월  Unnamed: 9  ...  2022년 04월  Unnamed: 439  \
# 0     52.863        0.66     52.967         0.2  ...    104.213         -0.01
#
#    2022년 05월  Unnamed: 441  2022년 06월  Unnamed: 443  2022년 07월  Unnamed: 445  \
# 0    104.201         -0.01    104.118         -0.08    103.885         -0.22
#
#    2022년 08월  Unnamed: 447
# 0    103.415         -0.45
#
# [1 rows x 448 columns]

# %%
seoul = seoul[seoul.columns.drop(list(seoul.filter(regex='Unnamed')))]
seoul
# Out:
#    2004년 01월  2004년 02월  2004년 03월  2004년 04월  2004년 05월  2004년 06월  \
# 0     51.936     52.246     52.519     52.863     52.967     52.863
#
#    2004년 07월  2004년 08월  2004년 09월  2004년 10월  ...  2021년 11월  2021년 12월  \
# 0      52.71     52.399     52.244     52.045  ...    104.122    104.377
#
#    2022년 01월  2022년 02월  2022년 03월  2022년 04월  2022년 05월  2022년 06월  \
# 0    104.382    104.297    104.223    104.213    104.201    104.118
#
#    2022년 07월  2022년 08월
# 0    103.885    103.415
#
# [1 rows x 224 columns]

# %%
seoul_col =seoul.columns
seoul_col
# Out:
# Index(['2004년 01월', '2004년 02월', '2004년 03월', '2004년 04월', '2004년 05월',
#        '2004년 06월', '2004년 07월', '2004년 08월', '2004년 09월', '2004년 10월',
#        ...
#        '2021년 11월', '2021년 12월', '2022년 01월', '2022년 02월', '2022년 03월',
#        '2022년 04월', '2022년 05월', '2022년 06월', '2022년 07월', '2022년 08월'],
#       dtype='object', length=224)

# %%
seoul_val = seoul.values
seoul_val
# Out:
# array([[ 51.936,  52.246,  52.519,  52.863,  52.967,  52.863,  52.71 ,
#          52.399,  52.244,  52.045,  51.808,  51.596,  51.463,  51.986,
#          52.237,  52.817,  53.299,  54.284,  55.237,  55.532,  55.646,
#          55.572,  55.73 ,  55.995,  56.442,  56.992,  57.924,  59.159,
#          60.302,  60.721,  60.91 ,  61.095,  61.552,  62.885,  66.593,
#          69.13 ,  70.733,  71.22 ,  71.494,  71.762,  71.766,  71.947,
#          72.258,  72.518,  72.862,  73.181,  73.677,  73.973,  74.518,
#          75.056,  76.395,  78.302,  79.484,  80.624,  81.237,  81.424,
#          81.61 ,  81.363,  80.636,  79.24 ,  78.515,  78.372,  78.167,
#          78.428,  78.592,  78.925,  79.596,  80.008,  80.916,  81.182,
#          81.189,  81.187,  81.252,  81.461,  81.448,  81.366,  80.998,
#          80.69 ,  80.3  ,  79.929,  79.727,  79.575,  79.479,  79.514,
#          79.626,  79.847,  79.958,  79.966,  79.994,  79.9  ,  79.771,
#          79.696,  79.599,  79.494,  79.348,  79.211,  78.997,  78.797,
#          78.456,  78.012,  77.588,  76.976,  76.456,  75.77 ,  75.264,
#          74.797,  74.42 ,  73.944,  73.482,  73.197,  73.107,  73.208,
#          73.38 ,  73.218,  72.83 ,  72.484,  72.55 ,  72.934,  73.022,
#          73.   ,  73.212,  73.462,  73.75 ,  73.776,  73.713,  73.661,
#          73.641,  73.726,  74.021,  74.336,  74.441,  74.452,  74.555,
#          74.785,  75.172,  75.74 ,  76.192,  76.711,  77.125,  77.554,
#          78.08 ,  78.606,  79.113,  79.446,  79.482,  79.483,  79.479,
#          79.556,  79.724,  79.994,  80.271,  80.583,  80.901,  81.459,
#          81.918,  82.025,  82.045,  82.1  ,  82.236,  82.463,  82.836,
#          83.659,  84.079,  84.59 ,  84.581,  84.8  ,  85.16 ,  85.873,
#          87.026,  88.231,  88.907,  89.239,  89.438,  89.63 ,  89.935,
#          90.674,  92.346,  92.881,  92.929,  92.773,  92.393,  92.053,
#          91.688,  91.373,  91.191,  91.108,  91.173,  91.302,  91.47 ,
#          92.018,  92.654,  93.801,  94.22 ,  94.331,  94.429,  94.337,
#          94.145,  94.27 ,  95.328,  95.849,  96.131,  96.241,  96.354,
#          96.626,  97.01 ,  97.658,  98.135,  98.557,  99.03 , 100.   ,
#         100.812, 101.74 , 102.657, 103.505, 104.122, 104.377, 104.382,
#         104.297, 104.223, 104.213, 104.201, 104.118, 103.885, 103.415]])

# %%
seoul = pd.DataFrame(index=seoul_col, data=seoul_val.T)
seoul
# Out:
#                  0
# 2004년 01월   51.936
# 2004년 02월   52.246
# 2004년 03월   52.519
# 2004년 04월   52.863
# 2004년 05월   52.967
# ...            ...
# 2022년 04월  104.213
# 2022년 05월  104.201
# 2022년 06월  104.118
# 2022년 07월  103.885
# 2022년 08월  103.415
#
# [224 rows x 1 columns]

# %%
seoul.reset_index()["index"].apply(change_date_to_time)
# Out:
# 0      2004-01
# 1      2004-02
# 2      2004-03
# 3      2004-04
# 4      2004-05
#          ...
# 219    2022-04
# 220    2022-05
# 221    2022-06
# 222    2022-07
# 223    2022-08
# Name: index, Length: 224, dtype: object

# %%
seoul = seoul.reset_index()
seoul["index"] = seoul["index"].apply(change_date_to_time)
seoul
# Out:
#         index        0
# 0    2004-01    51.936
# 1    2004-02    52.246
# 2    2004-03    52.519
# 3    2004-04    52.863
# 4    2004-05    52.967
# ..        ...      ...
# 219  2022-04   104.213
# 220  2022-05   104.201
# 221  2022-06   104.118
# 222  2022-07   103.885
# 223  2022-08   103.415
#
# [224 rows x 2 columns]

# %%
seoul.columns = ['Date', 'Price_index']
seoul
# Out:
#          Date  Price_index
# 0    2004-01        51.936
# 1    2004-02        52.246
# 2    2004-03        52.519
# 3    2004-04        52.863
# 4    2004-05        52.967
# ..        ...          ...
# 219  2022-04       104.213
# 220  2022-05       104.201
# 221  2022-06       104.118
# 222  2022-07       103.885
# 223  2022-08       103.415
#
# [224 rows x 2 columns]

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=seoul, x='Date', y='Price_index')
plt.show()

# %% [markdown]
# ## 월간 강남3구 아파트 매매 지수
#
# ------

# %%
gangnam
# Out:
#     지역  2004년 01월  Unnamed: 2  2004년 02월  Unnamed: 4  2004년 03월  Unnamed: 6  \
# 0  NaN     51.936       -0.30     52.246        0.60     52.519        0.52
# 1  서초구     49.209       -0.91     49.690        0.98     50.042        0.71
# 2  강남구     52.817       -0.33     53.740        1.75     54.093        0.66
# 3  송파구     53.462       -0.56     54.451        1.85     55.125        1.24
#
#    2004년 04월  Unnamed: 8  2004년 05월  ...  2022년 04월  Unnamed: 440  2022년 05월  \
# 0     52.863        0.66     52.967  ...    104.213         -0.01    104.201
# 1     50.054        0.02     50.346  ...    106.005          0.14    106.197
# 2     54.542        0.83     54.590  ...    106.007          0.14    106.102
# 3     56.363        2.25     56.185  ...    105.547          0.00    105.526
#
#    Unnamed: 442  2022년 06월  Unnamed: 444  2022년 07월  Unnamed: 446  2022년 08월  \
# 0         -0.01    104.118         -0.08    103.885         -0.22    103.415
# 1          0.18    106.297          0.09    106.378          0.08    106.300
# 2          0.09    106.112          0.01    106.068         -0.04    105.887
# 3         -0.02    105.442         -0.08    105.282         -0.15    104.822
#
#    Unnamed: 448
# 0         -0.45
# 1         -0.07
# 2         -0.17
# 3         -0.44
#
# [4 rows x 449 columns]

# %%
gangnam = gangnam[gangnam.columns.drop(list(gangnam.filter(regex='Unnamed')))]
gangnam
# Out:
#     지역  2004년 01월  2004년 02월  2004년 03월  2004년 04월  2004년 05월  2004년 06월  \
# 0  NaN     51.936     52.246     52.519     52.863     52.967     52.863
# 1  서초구     49.209     49.690     50.042     50.054     50.346     50.221
# 2  강남구     52.817     53.740     54.093     54.542     54.590     54.262
# 3  송파구     53.462     54.451     55.125     56.363     56.185     55.920
#
#    2004년 07월  2004년 08월  2004년 09월  ...  2021년 11월  2021년 12월  2022년 01월  \
# 0     52.710     52.399     52.244  ...    104.122    104.377    104.382
# 1     50.113     49.757     49.603  ...    105.172    105.739    105.833
# 2     53.862     53.208     52.855  ...    105.358    105.833    105.895
# 3     55.645     54.755     54.338  ...    105.265    105.588    105.651
#
#    2022년 02월  2022년 03월  2022년 04월  2022년 05월  2022년 06월  2022년 07월  2022년 08월
# 0    104.297    104.223    104.213    104.201    104.118    103.885    103.415
# 1    105.828    105.860    106.005    106.197    106.297    106.378    106.300
# 2    105.850    105.864    106.007    106.102    106.112    106.068    105.887
# 3    105.561    105.547    105.547    105.526    105.442    105.282    104.822
#
# [4 rows x 225 columns]

# %%
gangnam_col = gangnam.columns[1:]
gangnam_col
# Out:
# Index(['2004년 01월', '2004년 02월', '2004년 03월', '2004년 04월', '2004년 05월',
#        '2004년 06월', '2004년 07월', '2004년 08월', '2004년 09월', '2004년 10월',
#        ...
#        '2021년 11월', '2021년 12월', '2022년 01월', '2022년 02월', '2022년 03월',
#        '2022년 04월', '2022년 05월', '2022년 06월', '2022년 07월', '2022년 08월'],
#       dtype='object', length=224)

# %%
gangnam_val = gangnam.values[1:, 1:]
gangnam_val
# Out:
# array([[49.209, 49.69, 50.042, 50.054, 50.346, 50.221, 50.113, 49.757,
#         49.603, 49.337, 49.123, 48.993, 48.934, 49.959, 50.941, 53.048,
#         54.533, 58.128, 61.276, 61.261, 62.007, 61.606, 61.677, 62.05,
#         63.404, 64.539, 66.439, 69.406, 71.978, 71.959, 71.967, 72.157,
#         72.358, 73.309, 77.612, 78.846, 79.402, 79.344, 79.28, 79.255,
#         79.037, 78.972, 78.936, 78.877, 78.858, 78.864, 78.729, 78.648,
#         78.618, 78.641, 78.652, 78.865, 78.839, 78.773, 78.468, 78.352,
#         78.105, 77.385, 75.833, 73.565, 72.053, 71.65, 71.622, 72.611,
#         72.827, 73.256, 74.659, 75.443, 76.798, 77.021, 77.313, 77.231,
#         77.474, 78.31, 78.407, 78.352, 78.068, 77.825, 77.678, 77.625,
#         77.532, 77.481, 77.463, 77.708, 78.068, 78.709, 78.836, 78.89,
#         78.937, 78.864, 78.849, 78.857, 78.952, 78.916, 78.719, 78.585,
#         78.498, 77.759, 77.797, 77.173, 76.868, 76.286, 75.675, 75.318,
#         75.126, 74.964, 74.872, 74.39, 73.787, 73.563, 73.581, 73.593,
#         73.697, 73.542, 72.745, 72.228, 72.235, 72.422, 72.368, 72.345,
#         72.521, 72.747, 72.961, 73.018, 72.974, 72.977, 73.064, 73.173,
#         73.523, 73.796, 73.887, 73.898, 73.936, 74.254, 74.886, 75.654,
#         76.166, 76.821, 77.224, 77.704, 78.341, 78.846, 79.225, 79.575,
#         79.739, 79.711, 79.657, 79.737, 79.998, 80.608, 81.0, 81.324,
#         81.609, 82.409, 82.772, 82.663, 82.575, 82.605, 82.802, 83.107,
#         83.449, 84.515, 84.92, 85.147, 84.972, 85.021, 85.363, 86.614,
#         88.588, 90.781, 91.25, 91.329, 91.218, 91.094, 91.092, 91.649,
#         93.885, 94.374, 94.21, 93.924, 93.496, 92.84, 92.366, 91.847,
#         91.608, 91.572, 91.743, 91.985, 92.235, 92.77, 93.569, 95.438,
#         95.853, 95.68, 95.424, 94.53, 93.689, 93.73, 94.611, 94.923,
#         94.985, 95.015, 95.08, 95.478, 95.976, 96.634, 97.175, 97.676,
#         98.355, 100, 100.895, 101.896, 103.041, 104.19, 105.172, 105.739,
#         105.833, 105.828, 105.86, 106.005, 106.197, 106.297, 106.378,
#         106.3],
#        [52.817, 53.74, 54.093, 54.542, 54.59, 54.262, 53.862, 53.208,
#         52.855, 52.157, 51.62, 51.385, 51.053, 52.728, 53.02, 54.783,
#         55.875, 59.27, 61.672, 61.376, 60.661, 59.773, 60.421, 61.226,
#         62.43, 63.731, 65.706, 68.497, 70.357, 70.486, 70.331, 70.238,
#         70.51, 72.094, 76.553, 78.514, 79.261, 79.232, 79.175, 78.586,
#         78.068, 77.954, 78.139, 78.181, 78.134, 78.19, 78.375, 78.3,
#         78.487, 78.621, 78.88, 79.444, 79.721, 79.896, 79.618, 79.356,
#         79.354, 78.59, 76.748, 73.611, 72.746, 73.408, 73.466, 74.191,
#         74.452, 75.154, 76.349, 77.072, 78.343, 78.546, 78.341, 78.289,
#         78.387, 78.665, 78.712, 78.664, 78.045, 77.74, 77.529, 77.06,
#         76.93, 76.867, 76.741, 76.929, 77.172, 77.583, 77.682, 77.674,
#         77.651, 77.527, 77.33, 77.289, 77.163, 76.925, 76.773, 76.613,
#         75.817, 75.641, 75.087, 74.113, 73.678, 72.758, 72.367, 71.158,
#         69.943, 68.815, 68.58, 67.352, 66.505, 66.197, 66.313, 66.863,
#         67.485, 67.109, 66.597, 66.178, 66.534, 66.744, 66.731, 66.628,
#         66.828, 67.338, 67.902, 67.819, 67.794, 67.779, 67.876, 68.22,
#         68.831, 69.082, 69.056, 68.966, 69.225, 69.769, 70.631, 71.298,
#         71.89, 72.668, 73.408, 74.079, 74.6, 74.956, 75.424, 75.686,
#         75.464, 75.286, 75.252, 75.504, 76.042, 76.87, 77.506, 78.093,
#         78.818, 80.051, 80.401, 80.26, 80.068, 80.11, 80.411, 80.641,
#         81.086, 82.409, 82.66, 83.354, 83.21, 83.5, 84.113, 85.541,
#         88.702, 90.875, 91.763, 91.949, 91.779, 91.354, 91.064, 91.789,
#         93.866, 94.304, 94.119, 93.611, 92.55, 91.555, 90.745, 90.462,
#         90.414, 90.432, 90.603, 90.827, 91.005, 91.979, 92.956, 95.712,
#         96.28, 96.1, 95.779, 94.888, 94.019, 94.083, 94.975, 95.318,
#         95.461, 95.487, 95.525, 95.804, 96.258, 96.834, 97.373, 97.965,
#         98.672, 100, 100.948, 101.981, 103.324, 104.521, 105.358,
#         105.833, 105.895, 105.85, 105.864, 106.007, 106.102, 106.112,
#         106.068, 105.887],
#        [53.462, 54.451, 55.125, 56.363, 56.185, 55.92, 55.645, 54.755,
#         54.338, 54.179, 53.616, 53.403, 53.36, 54.866, 55.38, 56.967,
#         58.36, 61.375, 62.625, 62.688, 63.013, 62.666, 63.281, 64.145,
#         65.055, 66.018, 68.132, 69.853, 71.398, 71.763, 71.753, 71.376,
#         71.589, 73.204, 78.711, 80.395, 81.529, 81.509, 81.679, 81.371,
#         80.947, 80.832, 80.782, 80.786, 80.732, 80.567, 80.132, 79.934,
#         79.854, 79.791, 79.703, 79.668, 79.24, 78.75, 79.161, 78.865,
#         78.556, 77.666, 75.676, 73.567, 71.719, 72.291, 71.987, 72.424,
#         72.87, 73.382, 74.659, 75.344, 76.405, 76.873, 76.771, 76.749,
#         76.874, 77.256, 77.373, 77.314, 76.988, 76.725, 76.423, 75.873,
#         75.521, 75.344, 75.286, 75.506, 75.816, 76.108, 76.212, 76.138,
#         76.118, 76.02, 75.891, 75.809, 75.711, 75.558, 75.262, 75.0,
#         74.867, 73.936, 73.158, 72.978, 72.55, 71.184, 69.87, 69.059,
#         68.63, 68.174, 68.005, 67.653, 67.517, 67.513, 67.806, 68.14,
#         68.501, 68.144, 67.69, 67.498, 67.926, 68.96, 69.091, 69.292,
#         69.414, 69.627, 69.954, 70.03, 69.94, 69.893, 69.933, 70.007,
#         70.271, 70.615, 70.581, 70.544, 70.67, 70.842, 71.151, 71.646,
#         71.974, 72.38, 72.654, 72.963, 73.247, 73.721, 73.996, 74.282,
#         74.264, 74.238, 74.187, 74.222, 74.328, 74.562, 74.74, 74.87,
#         75.071, 75.525, 75.95, 75.88, 75.793, 75.833, 75.995, 76.227,
#         76.53, 77.798, 78.089, 78.876, 78.993, 79.948, 80.614, 82.497,
#         85.831, 88.0, 89.076, 89.262, 89.042, 88.68, 88.475, 89.185,
#         91.311, 91.793, 91.545, 91.081, 90.348, 89.896, 89.398, 89.138,
#         89.034, 89.005, 89.15, 89.306, 89.452, 90.375, 91.398, 93.901,
#         94.439, 94.256, 93.946, 93.333, 92.831, 93.154, 94.501, 94.82,
#         94.909, 94.943, 95.005, 95.263, 95.866, 96.731, 97.351, 97.931,
#         98.627, 100, 100.937, 102.095, 103.244, 104.407, 105.265,
#         105.588, 105.651, 105.561, 105.547, 105.547, 105.526, 105.442,
#         105.282, 104.822]], dtype=object)

# %%
gangnam = pd.DataFrame(index=gangnam_col, data=gangnam_val.T)
gangnam
# Out:
#                  0        1        2
# 2004년 01월   49.209   52.817   53.462
# 2004년 02월    49.69    53.74   54.451
# 2004년 03월   50.042   54.093   55.125
# 2004년 04월   50.054   54.542   56.363
# 2004년 05월   50.346    54.59   56.185
# ...            ...      ...      ...
# 2022년 04월  106.005  106.007  105.547
# 2022년 05월  106.197  106.102  105.526
# 2022년 06월  106.297  106.112  105.442
# 2022년 07월  106.378  106.068  105.282
# 2022년 08월    106.3  105.887  104.822
#
# [224 rows x 3 columns]

# %%
gangnam.reset_index()["index"].apply(change_date_to_time)
# Out:
# 0      2004-01
# 1      2004-02
# 2      2004-03
# 3      2004-04
# 4      2004-05
#          ...
# 219    2022-04
# 220    2022-05
# 221    2022-06
# 222    2022-07
# 223    2022-08
# Name: index, Length: 224, dtype: object

# %%
gangnam = gangnam.reset_index()
gangnam["index"] = gangnam["index"].apply(change_date_to_time)
gangnam
# Out:
#         index        0        1        2
# 0    2004-01    49.209   52.817   53.462
# 1    2004-02     49.69    53.74   54.451
# 2    2004-03    50.042   54.093   55.125
# 3    2004-04    50.054   54.542   56.363
# 4    2004-05    50.346    54.59   56.185
# ..        ...      ...      ...      ...
# 219  2022-04   106.005  106.007  105.547
# 220  2022-05   106.197  106.102  105.526
# 221  2022-06   106.297  106.112  105.442
# 222  2022-07   106.378  106.068  105.282
# 223  2022-08     106.3  105.887  104.822
#
# [224 rows x 4 columns]

# %%
gangnam.columns = ['Date', 'Seocho', 'Gangnam', 'Songpa']
gangnam
# Out:
#          Date   Seocho  Gangnam   Songpa
# 0    2004-01    49.209   52.817   53.462
# 1    2004-02     49.69    53.74   54.451
# 2    2004-03    50.042   54.093   55.125
# 3    2004-04    50.054   54.542   56.363
# 4    2004-05    50.346    54.59   56.185
# ..        ...      ...      ...      ...
# 219  2022-04   106.005  106.007  105.547
# 220  2022-05   106.197  106.102  105.526
# 221  2022-06   106.297  106.112  105.442
# 222  2022-07   106.378  106.068  105.282
# 223  2022-08     106.3  105.887  104.822
#
# [224 rows x 4 columns]

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=country, x='Date', y='Price_index')
sns.lineplot(data=apt, x='Date', y='Price_index')
sns.lineplot(data=seoul, x='Date', y='Price_index')

sns.lineplot(data=gangnam, x='Date', y='Seocho')
sns.lineplot(data=gangnam, x='Date', y='Gangnam')
sns.lineplot(data=gangnam, x='Date', y='Songpa')

plt.legend(labels = ['country', 'apt', 'seoul', 'Seocho', 'Gangnam', 'Songpa'], fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price_index', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 문제인 정권 주간 아파트 매매 지수
#
# ------

# %%
moon = pd.read_excel('./data/주간_매매가격지수_종합.xlsx')

# %%
moon
# Out:
#    지 역  2017년 05월01일  Unnamed: 2  2017년 05월08일  Unnamed: 4  2017년 05월15일  \
# 0   전국        88.561        0.02        88.581        0.02        88.606
# 1   서울        87.059        0.09        87.130        0.08        87.247
# 2  서초구        88.581        0.05        88.645        0.07        88.751
# 3  강남구        87.550        0.06        87.630        0.09        87.789
# 4  송파구        81.953        0.04        82.006        0.06        82.132
#
#    Unnamed: 6  2017년 05월22일  Unnamed: 8  2017년 05월29일  ...  2022년 05월02일  \
# 0        0.03        88.651        0.05        88.709  ...       106.210
# 1        0.13        87.420        0.20        87.665  ...       104.088
# 2        0.12        88.981        0.26        89.340  ...       105.814
# 3        0.18        88.021        0.26        88.462  ...       105.632
# 4        0.15        82.386        0.31        82.889  ...       105.265
#
#    Unnamed: 522  2022년 05월09일  Unnamed: 524  2022년 05월16일  Unnamed: 526  \
# 0          0.00       106.194         -0.01       106.187         -0.01
# 1          0.01       104.089          0.00       104.090          0.00
# 2          0.05       105.858          0.04       105.935          0.07
# 3          0.03       105.655          0.02       105.685          0.03
# 4         -0.01       105.265          0.00       105.270          0.00
#
#    2022년 05월23일  Unnamed: 528  2022년 05월30일  Unnamed: 530
# 0       106.176         -0.01       106.164         -0.01
# 1       104.089          0.00       104.082         -0.01
# 2       105.974          0.04       105.982          0.01
# 3       105.706          0.02       105.721          0.01
# 4       105.264         -0.01       105.250         -0.01
#
# [5 rows x 531 columns]

# %%
moon = moon[moon.columns.drop(list(moon.filter(regex='Unnamed')))]
moon
# Out:
#    지 역  2017년 05월01일  2017년 05월08일  2017년 05월15일  2017년 05월22일  2017년 05월29일  \
# 0   전국        88.561        88.581        88.606        88.651        88.709
# 1   서울        87.059        87.130        87.247        87.420        87.665
# 2  서초구        88.581        88.645        88.751        88.981        89.340
# 3  강남구        87.550        87.630        87.789        88.021        88.462
# 4  송파구        81.953        82.006        82.132        82.386        82.889
#
#    2017년 06월05일  2017년 06월12일  2017년 06월19일  2017년 06월26일  ...  2022년 03월28일  \
# 0        88.762        88.799        88.822        88.844  ...       106.212
# 1        87.911        88.072        88.174        88.266  ...       104.086
# 2        89.730        90.047        90.096        90.160  ...       105.635
# 3        88.890        89.096        89.127        89.127  ...       105.473
# 4        83.319        83.588        83.613        83.626  ...       105.271
#
#    2022년 04월04일  2022년 04월11일  2022년 04월18일  2022년 04월25일  2022년 05월02일  \
# 0       106.206       106.208       106.207       106.204       106.210
# 1       104.081       104.080       104.082       104.083       104.088
# 2       105.656       105.676       105.707       105.761       105.814
# 3       105.493       105.535       105.565       105.597       105.632
# 4       105.285       105.276       105.280       105.275       105.265
#
#    2022년 05월09일  2022년 05월16일  2022년 05월23일  2022년 05월30일
# 0       106.194       106.187       106.176       106.164
# 1       104.089       104.090       104.089       104.082
# 2       105.858       105.935       105.974       105.982
# 3       105.655       105.685       105.706       105.721
# 4       105.265       105.270       105.264       105.250
#
# [5 rows x 266 columns]

# %%
moon_col = moon.columns[1:]
moon_col
# Out:
# Index(['2017년 05월01일', '2017년 05월08일', '2017년 05월15일', '2017년 05월22일',
#        '2017년 05월29일', '2017년 06월05일', '2017년 06월12일', '2017년 06월19일',
#        '2017년 06월26일', '2017년 07월03일',
#        ...
#        '2022년 03월28일', '2022년 04월04일', '2022년 04월11일', '2022년 04월18일',
#        '2022년 04월25일', '2022년 05월02일', '2022년 05월09일', '2022년 05월16일',
#        '2022년 05월23일', '2022년 05월30일'],
#       dtype='object', length=265)

# %%
moon_val = moon.values[:, 1:]
moon_val
# Out:
# array([[88.561, 88.581, 88.606, ..., 106.187, 106.176, 106.164],
#        [87.059, 87.13, 87.247, ..., 104.09, 104.089, 104.082],
#        [88.581, 88.645, 88.751, ..., 105.935, 105.974, 105.982],
#        [87.55, 87.63, 87.789, ..., 105.685, 105.706, 105.721],
#        [81.953, 82.006, 82.132, ..., 105.27, 105.264, 105.25]],
#       dtype=object)

# %%
moon = pd.DataFrame(index=moon_col, data=moon_val.T)
moon
# Out:
#                     0        1        2        3        4
# 2017년 05월01일   88.561   87.059   88.581    87.55   81.953
# 2017년 05월08일   88.581    87.13   88.645    87.63   82.006
# 2017년 05월15일   88.606   87.247   88.751   87.789   82.132
# 2017년 05월22일   88.651    87.42   88.981   88.021   82.386
# 2017년 05월29일   88.709   87.665    89.34   88.462   82.889
# ...               ...      ...      ...      ...      ...
# 2022년 05월02일   106.21  104.088  105.814  105.632  105.265
# 2022년 05월09일  106.194  104.089  105.858  105.655  105.265
# 2022년 05월16일  106.187   104.09  105.935  105.685   105.27
# 2022년 05월23일  106.176  104.089  105.974  105.706  105.264
# 2022년 05월30일  106.164  104.082  105.982  105.721   105.25
#
# [265 rows x 5 columns]

# %%
def change_date_to_time2(x):
    x = x.replace("년 ", "-")
    x = x.replace("월" , "-")
    x = x.replace("일", " ")
    return x

# %%
moon.reset_index()["index"].apply(change_date_to_time2)
# Out:
# 0      2017-05-01
# 1      2017-05-08
# 2      2017-05-15
# 3      2017-05-22
# 4      2017-05-29
#           ...
# 260    2022-05-02
# 261    2022-05-09
# 262    2022-05-16
# 263    2022-05-23
# 264    2022-05-30
# Name: index, Length: 265, dtype: object

# %%
moon = moon.reset_index()
moon["index"] = moon["index"].apply(change_date_to_time2)
moon
# Out:
#            index        0        1        2        3        4
# 0    2017-05-01    88.561   87.059   88.581    87.55   81.953
# 1    2017-05-08    88.581    87.13   88.645    87.63   82.006
# 2    2017-05-15    88.606   87.247   88.751   87.789   82.132
# 3    2017-05-22    88.651    87.42   88.981   88.021   82.386
# 4    2017-05-29    88.709   87.665    89.34   88.462   82.889
# ..           ...      ...      ...      ...      ...      ...
# 260  2022-05-02    106.21  104.088  105.814  105.632  105.265
# 261  2022-05-09   106.194  104.089  105.858  105.655  105.265
# 262  2022-05-16   106.187   104.09  105.935  105.685   105.27
# 263  2022-05-23   106.176  104.089  105.974  105.706  105.264
# 264  2022-05-30   106.164  104.082  105.982  105.721   105.25
#
# [265 rows x 6 columns]

# %%
moon.columns = ['Date', 'Country', 'Seoul', 'Seocho', 'Gangnam', 'Songpa']
moon
# Out:
#             Date  Country    Seoul   Seocho  Gangnam   Songpa
# 0    2017-05-01    88.561   87.059   88.581    87.55   81.953
# 1    2017-05-08    88.581    87.13   88.645    87.63   82.006
# 2    2017-05-15    88.606   87.247   88.751   87.789   82.132
# 3    2017-05-22    88.651    87.42   88.981   88.021   82.386
# 4    2017-05-29    88.709   87.665    89.34   88.462   82.889
# ..           ...      ...      ...      ...      ...      ...
# 260  2022-05-02    106.21  104.088  105.814  105.632  105.265
# 261  2022-05-09   106.194  104.089  105.858  105.655  105.265
# 262  2022-05-16   106.187   104.09  105.935  105.685   105.27
# 263  2022-05-23   106.176  104.089  105.974  105.706  105.264
# 264  2022-05-30   106.164  104.082  105.982  105.721   105.25
#
# [265 rows x 6 columns]

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=moon, x='Date', y='Country')
sns.lineplot(data=moon, x='Date', y='Seoul')
sns.lineplot(data=moon, x='Date', y='Seocho')
sns.lineplot(data=moon, x='Date', y='Gangnam')
sns.lineplot(data=moon, x='Date', y='Songpa')

plt.legend(labels = ['Country', 'Seoul', 'Seocho', 'Gangnam', 'Songpa'], fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price_index', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 문제인 정권 2019년 주간 아파트 매매 지수
#
# ------

# %%
moon_2019 = pd.read_excel('./data/주간_매매가격지수_2019.xlsx')
moon_2019
# Out:
#    2018년 12월31일  Unnamed: 1  2019년 01월07일  Unnamed: 3  2019년 01월14일  \
# 0        88.934       -0.07        88.866       -0.08        88.804
#
#    Unnamed: 5  2019년 01월21일  Unnamed: 7  2019년 01월28일  Unnamed: 9  ...  \
# 0       -0.07        88.733       -0.08        88.644        -0.1  ...
#
#    2019년 07월01일  Unnamed: 53  2019년 07월08일  Unnamed: 55  2019년 07월15일  \
# 0        87.094        -0.06         87.06        -0.04        87.025
#
#    Unnamed: 57  2019년 07월22일  Unnamed: 59  2019년 07월29일  Unnamed: 61
# 0        -0.04        86.976        -0.06        86.948        -0.03
#
# [1 rows x 62 columns]

# %%
moon_2019 = moon_2019[moon_2019.columns.drop(list(moon_2019.filter(regex='Unnamed')))]
moon_2019
# Out:
#    2018년 12월31일  2019년 01월07일  2019년 01월14일  2019년 01월21일  2019년 01월28일  \
# 0        88.934        88.866        88.804        88.733        88.644
#
#    2019년 02월04일  2019년 02월11일  2019년 02월18일  2019년 02월25일  2019년 03월04일  ...  \
# 0        88.589        88.526        88.449        88.374        88.298  ...
#
#    2019년 05월27일  2019년 06월03일  2019년 06월10일  2019년 06월17일  2019년 06월24일  \
# 0        87.381        87.325         87.27        87.207        87.143
#
#    2019년 07월01일  2019년 07월08일  2019년 07월15일  2019년 07월22일  2019년 07월29일
# 0        87.094         87.06        87.025        86.976        86.948
#
# [1 rows x 31 columns]

# %%
moon_2019_col = moon_2019.columns
moon_2019_col
# Out:
# Index(['2018년 12월31일', '2019년 01월07일', '2019년 01월14일', '2019년 01월21일',
#        '2019년 01월28일', '2019년 02월04일', '2019년 02월11일', '2019년 02월18일',
#        '2019년 02월25일', '2019년 03월04일', '2019년 03월11일', '2019년 03월18일',
#        '2019년 03월25일', '2019년 04월01일', '2019년 04월08일', '2019년 04월15일',
#        '2019년 04월22일', '2019년 04월29일', '2019년 05월06일', '2019년 05월13일',
#        '2019년 05월20일', '2019년 05월27일', '2019년 06월03일', '2019년 06월10일',
#        '2019년 06월17일', '2019년 06월24일', '2019년 07월01일', '2019년 07월08일',
#        '2019년 07월15일', '2019년 07월22일', '2019년 07월29일'],
#       dtype='object')

# %%
moon_2019_val = moon_2019.values
moon_2019_val
# Out:
# array([[88.934, 88.866, 88.804, 88.733, 88.644, 88.589, 88.526, 88.449,
#         88.374, 88.298, 88.218, 88.15 , 88.063, 87.967, 87.888, 87.811,
#         87.726, 87.655, 87.584, 87.51 , 87.447, 87.381, 87.325, 87.27 ,
#         87.207, 87.143, 87.094, 87.06 , 87.025, 86.976, 86.948]])

# %%
moon_2019 = pd.DataFrame(index=moon_2019_col, data=moon_2019_val.T)
moon_2019
# Out:
#                    0
# 2018년 12월31일  88.934
# 2019년 01월07일  88.866
# 2019년 01월14일  88.804
# 2019년 01월21일  88.733
# 2019년 01월28일  88.644
# 2019년 02월04일  88.589
# 2019년 02월11일  88.526
# 2019년 02월18일  88.449
# 2019년 02월25일  88.374
# 2019년 03월04일  88.298
# 2019년 03월11일  88.218
# 2019년 03월18일  88.150
# 2019년 03월25일  88.063
# 2019년 04월01일  87.967
# 2019년 04월08일  87.888
# 2019년 04월15일  87.811
# 2019년 04월22일  87.726
# 2019년 04월29일  87.655
# 2019년 05월06일  87.584
# 2019년 05월13일  87.510
# 2019년 05월20일  87.447
# 2019년 05월27일  87.381
# 2019년 06월03일  87.325
# 2019년 06월10일  87.270
# 2019년 06월17일  87.207
# 2019년 06월24일  87.143
# 2019년 07월01일  87.094
# 2019년 07월08일  87.060
# 2019년 07월15일  87.025
# 2019년 07월22일  86.976
# 2019년 07월29일  86.948

# %%
moon_2019.reset_index()["index"].apply(change_date_to_time2)
# Out:
# 0     2018-12-31
# 1     2019-01-07
# 2     2019-01-14
# 3     2019-01-21
# 4     2019-01-28
# 5     2019-02-04
# 6     2019-02-11
# 7     2019-02-18
# 8     2019-02-25
# 9     2019-03-04
# 10    2019-03-11
# 11    2019-03-18
# 12    2019-03-25
# 13    2019-04-01
# 14    2019-04-08
# 15    2019-04-15
# 16    2019-04-22
# 17    2019-04-29
# 18    2019-05-06
# 19    2019-05-13
# 20    2019-05-20
# 21    2019-05-27
# 22    2019-06-03
# 23    2019-06-10
# 24    2019-06-17
# 25    2019-06-24
# 26    2019-07-01
# 27    2019-07-08
# 28    2019-07-15
# 29    2019-07-22
# 30    2019-07-29
# Name: index, dtype: object

# %%
moon_2019 = moon_2019.reset_index()
moon_2019["index"] = moon_2019["index"].apply(change_date_to_time2)
moon_2019
# Out:
#           index       0
# 0   2018-12-31   88.934
# 1   2019-01-07   88.866
# 2   2019-01-14   88.804
# 3   2019-01-21   88.733
# 4   2019-01-28   88.644
# 5   2019-02-04   88.589
# 6   2019-02-11   88.526
# 7   2019-02-18   88.449
# 8   2019-02-25   88.374
# 9   2019-03-04   88.298
# 10  2019-03-11   88.218
# 11  2019-03-18   88.150
# 12  2019-03-25   88.063
# 13  2019-04-01   87.967
# 14  2019-04-08   87.888
# 15  2019-04-15   87.811
# 16  2019-04-22   87.726
# 17  2019-04-29   87.655
# 18  2019-05-06   87.584
# 19  2019-05-13   87.510
# 20  2019-05-20   87.447
# 21  2019-05-27   87.381
# 22  2019-06-03   87.325
# 23  2019-06-10   87.270
# 24  2019-06-17   87.207
# 25  2019-06-24   87.143
# 26  2019-07-01   87.094
# 27  2019-07-08   87.060
# 28  2019-07-15   87.025
# 29  2019-07-22   86.976
# 30  2019-07-29   86.948

# %%
moon_2019.columns = ['Date', 'Price_index']
moon_2019
# Out:
#            Date  Price_index
# 0   2018-12-31        88.934
# 1   2019-01-07        88.866
# 2   2019-01-14        88.804
# 3   2019-01-21        88.733
# 4   2019-01-28        88.644
# 5   2019-02-04        88.589
# 6   2019-02-11        88.526
# 7   2019-02-18        88.449
# 8   2019-02-25        88.374
# 9   2019-03-04        88.298
# 10  2019-03-11        88.218
# 11  2019-03-18        88.150
# 12  2019-03-25        88.063
# 13  2019-04-01        87.967
# 14  2019-04-08        87.888
# 15  2019-04-15        87.811
# 16  2019-04-22        87.726
# 17  2019-04-29        87.655
# 18  2019-05-06        87.584
# 19  2019-05-13        87.510
# 20  2019-05-20        87.447
# 21  2019-05-27        87.381
# 22  2019-06-03        87.325
# 23  2019-06-10        87.270
# 24  2019-06-17        87.207
# 25  2019-06-24        87.143
# 26  2019-07-01        87.094
# 27  2019-07-08        87.060
# 28  2019-07-15        87.025
# 29  2019-07-22        86.976
# 30  2019-07-29        86.948

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=moon_2019, x='Date', y='Price_index')

plt.legend(labels = ['Price_index'], fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price_index', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 박근혜 정권 주간 아파트 매매 지수
#
# ------

# %%
park = pd.read_excel('./data/주간_매매가격지수_박근혜.xlsx')

# %%
park
# Out:
#    2013년 01월28일  Unnamed: 1  2013년 02월04일  Unnamed: 3  2013년 02월11일  \
# 0        78.923       -0.07        78.885       -0.05         78.84
#
#    Unnamed: 5  2013년 02월18일  Unnamed: 7  2013년 02월25일  Unnamed: 9  ...  \
# 0       -0.06        78.803       -0.05        78.785       -0.02  ...
#
#    2017년 02월27일  Unnamed: 427  2017년 03월06일  Unnamed: 429  2017년 03월13일  \
# 0        88.447             0        88.454          0.01        88.464
#
#    Unnamed: 431  2017년 03월20일  Unnamed: 433  2017년 03월27일  Unnamed: 435
# 0          0.01        88.481          0.02        88.487          0.01
#
# [1 rows x 436 columns]

# %%
park = park[park.columns.drop(list(park.filter(regex='Unnamed')))]
park
# Out:
#    2013년 01월28일  2013년 02월04일  2013년 02월11일  2013년 02월18일  2013년 02월25일  \
# 0        78.923        78.885         78.84        78.803        78.785
#
#    2013년 03월04일  2013년 03월11일  2013년 03월18일  2013년 03월25일  2013년 04월01일  ...  \
# 0        78.763        78.753        78.747        78.757        78.798  ...
#
#    2017년 01월23일  2017년 01월30일  2017년 02월06일  2017년 02월13일  2017년 02월20일  \
# 0        88.453        88.447        88.439         88.44        88.442
#
#    2017년 02월27일  2017년 03월06일  2017년 03월13일  2017년 03월20일  2017년 03월27일
# 0        88.447        88.454        88.464        88.481        88.487
#
# [1 rows x 218 columns]

# %%
park_col = park.columns
park_col
# Out:
# Index(['2013년 01월28일', '2013년 02월04일', '2013년 02월11일', '2013년 02월18일',
#        '2013년 02월25일', '2013년 03월04일', '2013년 03월11일', '2013년 03월18일',
#        '2013년 03월25일', '2013년 04월01일',
#        ...
#        '2017년 01월23일', '2017년 01월30일', '2017년 02월06일', '2017년 02월13일',
#        '2017년 02월20일', '2017년 02월27일', '2017년 03월06일', '2017년 03월13일',
#        '2017년 03월20일', '2017년 03월27일'],
#       dtype='object', length=218)

# %%
park_val = park.values
park_val
# Out:
# array([[78.923, 78.885, 78.84 , 78.803, 78.785, 78.763, 78.753, 78.747,
#         78.757, 78.798, 78.878, 78.966, 79.041, 79.113, 79.191, 79.28 ,
#         79.333, 79.373, 79.389, 79.406, 79.418, 79.432, 79.434, 79.416,
#         79.389, 79.358, 79.332, 79.296, 79.261, 79.245, 79.233, 79.257,
#         79.319, 79.375, 79.426, 79.503, 79.646, 79.758, 79.835, 79.917,
#         79.981, 80.05 , 80.107, 80.151, 80.192, 80.261, 80.325, 80.4  ,
#         80.465, 80.534, 80.61 , 80.682, 80.765, 80.834, 80.918, 80.999,
#         81.09 , 81.193, 81.273, 81.327, 81.344, 81.368, 81.377, 81.39 ,
#         81.388, 81.393, 81.388, 81.39 , 81.391, 81.394, 81.396, 81.41 ,
#         81.415, 81.41 , 81.422, 81.437, 81.459, 81.478, 81.51 , 81.539,
#         81.585, 81.636, 81.717, 81.801, 81.878, 81.953, 82.038, 82.127,
#         82.225, 82.316, 82.388, 82.449, 82.505, 82.559, 82.61 , 82.658,
#         82.702, 82.745, 82.778, 82.813, 82.849, 82.9  , 82.949, 82.998,
#         83.069, 83.151, 83.241, 83.343, 83.422, 83.529, 83.656, 83.781,
#         83.916, 84.067, 84.202, 84.344, 84.478, 84.581, 84.685, 84.785,
#         84.894, 85.01 , 85.105, 85.209, 85.311, 85.422, 85.533, 85.621,
#         85.698, 85.795, 85.891, 85.98 , 86.066, 86.149, 86.247, 86.337,
#         86.441, 86.547, 86.656, 86.759, 86.867, 86.985, 87.101, 87.217,
#         87.336, 87.433, 87.516, 87.587, 87.634, 87.678, 87.702, 87.713,
#         87.712, 87.715, 87.714, 87.712, 87.708, 87.707, 87.703, 87.697,
#         87.685, 87.678, 87.666, 87.655, 87.644, 87.634, 87.635, 87.638,
#         87.638, 87.644, 87.644, 87.647, 87.65 , 87.653, 87.657, 87.657,
#         87.668, 87.68 , 87.691, 87.702, 87.709, 87.727, 87.74 , 87.753,
#         87.768, 87.779, 87.8  , 87.824, 87.855, 87.887, 87.923, 87.982,
#         88.053, 88.126, 88.2  , 88.264, 88.319, 88.364, 88.397, 88.426,
#         88.447, 88.457, 88.463, 88.464, 88.463, 88.459, 88.458, 88.458,
#         88.453, 88.447, 88.439, 88.44 , 88.442, 88.447, 88.454, 88.464,
#         88.481, 88.487]])

# %%
park = pd.DataFrame(index=park_col, data=park_val.T)
park
# Out:
#                    0
# 2013년 01월28일  78.923
# 2013년 02월04일  78.885
# 2013년 02월11일  78.840
# 2013년 02월18일  78.803
# 2013년 02월25일  78.785
# ...              ...
# 2017년 02월27일  88.447
# 2017년 03월06일  88.454
# 2017년 03월13일  88.464
# 2017년 03월20일  88.481
# 2017년 03월27일  88.487
#
# [218 rows x 1 columns]

# %%
park.reset_index()["index"].apply(change_date_to_time2)
# Out:
# 0      2013-01-28
# 1      2013-02-04
# 2      2013-02-11
# 3      2013-02-18
# 4      2013-02-25
#           ...
# 213    2017-02-27
# 214    2017-03-06
# 215    2017-03-13
# 216    2017-03-20
# 217    2017-03-27
# Name: index, Length: 218, dtype: object

# %%
park = park.reset_index()
park["index"] = park["index"].apply(change_date_to_time2)
park
# Out:
#            index       0
# 0    2013-01-28   78.923
# 1    2013-02-04   78.885
# 2    2013-02-11   78.840
# 3    2013-02-18   78.803
# 4    2013-02-25   78.785
# ..           ...     ...
# 213  2017-02-27   88.447
# 214  2017-03-06   88.454
# 215  2017-03-13   88.464
# 216  2017-03-20   88.481
# 217  2017-03-27   88.487
#
# [218 rows x 2 columns]

# %%
park.columns = ['Date', 'Price_index']
park
# Out:
#             Date  Price_index
# 0    2013-01-28        78.923
# 1    2013-02-04        78.885
# 2    2013-02-11        78.840
# 3    2013-02-18        78.803
# 4    2013-02-25        78.785
# ..           ...          ...
# 213  2017-02-27        88.447
# 214  2017-03-06        88.454
# 215  2017-03-13        88.464
# 216  2017-03-20        88.481
# 217  2017-03-27        88.487
#
# [218 rows x 2 columns]

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=park, x='Date', y='Price_index')

plt.legend(labels = ['Price_index'], fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('Price_index', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## OECD 경기선행지수
#
# ------

# %%
oecd = pd.read_csv('./data/DP_LIVE_13102022121757610.csv')

# %%
oecd
# Out:
#       LOCATION INDICATOR   SUBJECT    MEASURE FREQUENCY     TIME     Value  \
# 0          GBR       CLI  AMPLITUD  LTRENDIDX         M  2000-11  100.5146
# 1          GBR       CLI  AMPLITUD  LTRENDIDX         M  2000-12  100.5682
# 2          GBR       CLI  AMPLITUD  LTRENDIDX         M  2001-01  100.5774
# 3          GBR       CLI  AMPLITUD  LTRENDIDX         M  2001-02  100.5518
# 4          GBR       CLI  AMPLITUD  LTRENDIDX         M  2001-03  100.5025
# ...        ...       ...       ...        ...       ...      ...       ...
# 11284      COL       CLI  AMPLITUD  LTRENDIDX         M  2022-05  100.9315
# 11285      COL       CLI  AMPLITUD  LTRENDIDX         M  2022-06  100.9200
# 11286      COL       CLI  AMPLITUD  LTRENDIDX         M  2022-07  100.9201
# 11287      COL       CLI  AMPLITUD  LTRENDIDX         M  2022-08  100.8759
# 11288      COL       CLI  AMPLITUD  LTRENDIDX         M  2022-09  100.8049
#
#        Flag Codes
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 11284         NaN
# 11285         NaN
# 11286         NaN
# 11287         NaN
# 11288         NaN
#
# [11289 rows x 8 columns]

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=oecd, x='TIME', y='Value')

plt.legend(labels = ['Value'], fontsize=20)
plt.xlabel('TIME', fontsize=20)
plt.ylabel('Value', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 주요국 경기 선행지수
#
# ------

# %%
economic_idx = pd.read_csv('./data/경기선행지수.csv', encoding='cp949')
economic_idx
# Out:
#          국가  2000.01  2000.02  2000.03  2000.04  2000.05  2000.06  2000.07  \
# 0        일본   90.119   90.271   90.377   90.440   90.464   90.466   90.443
# 1      대한민국   54.792   54.806   54.832   54.886   54.951   55.009   55.030
# 2        영국   77.099   77.217   77.361   77.508   77.662   77.815   77.975
# 3        미국   74.160   74.319   74.451   74.564   74.654   74.727   74.784
# 4      유로지역   85.514   85.828   86.111   86.356   86.561   86.730   86.872
# 5  [비회원국]중국   15.671   15.802   15.931   16.049   16.156   16.254   16.343
#
#    2000.08  2000.09  ...  2021.05  2021.06  2021.07  2021.08  2021.09  \
# 0   90.410   90.370  ...  101.252  101.270  101.211  101.099  100.966
# 1   54.997   54.897  ...  117.595  117.736  117.752  117.667  117.510
# 2   78.155   78.362  ...  109.698  110.063  110.308  110.432  110.452
# 3   74.813   74.812  ...  113.063  113.188  113.257  113.301  113.358
# 4   86.985   87.064  ...  110.603  111.027  111.300  111.447  111.497
# 5   16.424   16.504  ...  152.916  153.355  153.735  154.092  154.473
#
#     2021.1  2021.11  2021.12  2022.01  2022.02
# 0  100.847  100.765  100.720  100.693  100.657
# 1  117.337  117.195  117.091  117.015  116.947
# 2  110.392  110.230  109.927  109.484  108.934
# 3  113.427  113.500  113.554  113.572  113.554
# 4  111.466  111.373  111.234  111.050  110.827
# 5  154.947  155.560  156.268  157.010  157.776
#
# [6 rows x 267 columns]

# %%
economic_idx_col = economic_idx.columns[1:]
economic_idx_col
# Out:
# Index(['2000.01', '2000.02', '2000.03', '2000.04', '2000.05', '2000.06',
#        '2000.07', '2000.08', '2000.09', '2000.1',
#        ...
#        '2021.05', '2021.06', '2021.07', '2021.08', '2021.09', '2021.1',
#        '2021.11', '2021.12', '2022.01', '2022.02'],
#       dtype='object', length=266)

# %%
economic_idx_val = economic_idx.values[:, 1:]
economic_idx_val
# Out:
# array([[90.119, 90.271, 90.377, ..., 100.72, 100.693, 100.657],
#        [54.792, 54.806, 54.832, ..., 117.091, 117.015, 116.947],
#        [77.099, 77.217, 77.361, ..., 109.927, 109.484, 108.934],
#        [74.16, 74.319, 74.451, ..., 113.554, 113.572, 113.554],
#        [85.514, 85.828, 86.111, ..., 111.234, 111.05, 110.827],
#        [15.671, 15.802, 15.931, ..., 156.268, 157.01, 157.776]],
#       dtype=object)

# %%
economic_idx = pd.DataFrame(index=economic_idx_col, data=economic_idx_val.T)
economic_idx
# Out:
#                0        1        2        3        4        5
# 2000.01   90.119   54.792   77.099    74.16   85.514   15.671
# 2000.02   90.271   54.806   77.217   74.319   85.828   15.802
# 2000.03   90.377   54.832   77.361   74.451   86.111   15.931
# 2000.04    90.44   54.886   77.508   74.564   86.356   16.049
# 2000.05   90.464   54.951   77.662   74.654   86.561   16.156
# ...          ...      ...      ...      ...      ...      ...
# 2021.1   100.847  117.337  110.392  113.427  111.466  154.947
# 2021.11  100.765  117.195   110.23    113.5  111.373   155.56
# 2021.12   100.72  117.091  109.927  113.554  111.234  156.268
# 2022.01  100.693  117.015  109.484  113.572   111.05   157.01
# 2022.02  100.657  116.947  108.934  113.554  110.827  157.776
#
# [266 rows x 6 columns]

# %%
economic_idx.index = pd.to_datetime(economic_idx.index, format = '%Y/%m')
economic_idx.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-02-01', '2000-03-01', '2000-04-01',
#                '2000-05-01', '2000-06-01', '2000-07-01', '2000-08-01',
#                '2000-09-01', '2000-01-01',
#                ...
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-01-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01'],
#               dtype='datetime64[ns]', length=266, freq=None)

# %%
economic_idx = economic_idx.reset_index()
economic_idx["index"] = economic_idx["index"]
economic_idx
# Out:
#          index        0        1        2        3        4        5
# 0   2000-01-01   90.119   54.792   77.099    74.16   85.514   15.671
# 1   2000-02-01   90.271   54.806   77.217   74.319   85.828   15.802
# 2   2000-03-01   90.377   54.832   77.361   74.451   86.111   15.931
# 3   2000-04-01    90.44   54.886   77.508   74.564   86.356   16.049
# 4   2000-05-01   90.464   54.951   77.662   74.654   86.561   16.156
# ..         ...      ...      ...      ...      ...      ...      ...
# 261 2021-01-01  100.847  117.337  110.392  113.427  111.466  154.947
# 262 2021-11-01  100.765  117.195   110.23    113.5  111.373   155.56
# 263 2021-12-01   100.72  117.091  109.927  113.554  111.234  156.268
# 264 2022-01-01  100.693  117.015  109.484  113.572   111.05   157.01
# 265 2022-02-01  100.657  116.947  108.934  113.554  110.827  157.776
#
# [266 rows x 7 columns]

# %%
economic_idx.columns = ['Date', 'Japan', 'Korea', 'UK', 'USA', 'Euro', 'China']
economic_idx['Date'].info
# Out:
# <bound method Series.info of 0     2000-01-01
# 1     2000-02-01
# 2     2000-03-01
# 3     2000-04-01
# 4     2000-05-01
#          ...
# 261   2021-01-01
# 262   2021-11-01
# 263   2021-12-01
# 264   2022-01-01
# 265   2022-02-01
# Name: Date, Length: 266, dtype: datetime64[ns]>

# %%
plt.figure(figsize = (30,15))
# sns.set(font_scale=2)

sns.lineplot(data=economic_idx, x='Date', y='Japan')
sns.lineplot(data=economic_idx, x='Date', y='Korea')
sns.lineplot(data=economic_idx, x='Date', y='UK')
sns.lineplot(data=economic_idx, x='Date', y='USA')
sns.lineplot(data=economic_idx, x='Date', y='Euro')
sns.lineplot(data=economic_idx, x='Date', y='China')

plt.legend(labels = ['Japan', 'Korea', 'UK', 'USA', 'Euro', 'China'], fontsize=20)
plt.xlabel('Date', fontsize=20)
plt.ylabel('economic', fontsize=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
